# %% [markdown]
# ### SEGMENTACIÓN MEDIANTE THRESHOLDING

# %%
import matplotlib.pyplot as plt
import cv2

# Read an image
img = cv2.imread('./figuras.png')
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
plt.title('Imagen Convertida a RGB')
plt.show()

plt.imshow(img)
plt.title('Imagen original')
plt.show()

# %%
from google.colab.patches import cv2_imshow

import matplotlib.pyplot as plt
import cv2

# Read an image
img = cv2.imread('./figuras.png')
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

cv2_imshow(img)
print()
cv2_imshow(img_rgb)
# Out:
# <PIL.Image.Image image mode=RGB size=586x523>
# <PIL.Image.Image image mode=RGB size=586x523>

# %%
# Convertimos la imagen a escala de grises
import numpy as np
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#gray_img = cv2.imread('figuras.png', 0) # Una forma de leer la imagen directamente en escala de grises

plt.imshow(gray_img, cmap='gray')
plt.title('Imagen de grises')
plt.show()

print(gray_img[gray_img != 0])
print(np.unique(gray_img))
print(gray_img.shape )
# Out:
# [185 190 189 ... 153 156 156]
# [  0  29  76  89  96 104 110 113 119 121 123 124 125 126 127 128 129 130
#  131 132 133 134 135 136 137 139 141 142 143 146 149 150 151 152 153 154
#  155 156 157 160 170 174 177 179 180 183 184 185 186 187 188 189 190 191
#  192 193 194 195 196 198 199 200 206 220 226 255]
# (523, 586)

# %%
figs_grays_values = {}
figs_grays_values['free_hand_figure_thr'] = 188
figs_grays_values['ray_thr'] = 130
figs_grays_values['square_thr'] = 109
figs_grays_values['circle_thr'] = 75
figs_grays_values['triangle_thr'] = 152
figs_grays_values['diamond_thr'] = 153

print("Pixel values:")
print("-- Figura a mano:", gray_img[100,100])
print("-- Rayo:         ", gray_img[75,400])
print("-- Rectangulo:   ", gray_img[250,100])
print("-- Circulo:      ", gray_img[250,400])
print("-- Triangulo:    ", gray_img[400,250])
print("-- Diamon:       ", gray_img[450,500])
# Out:
# Pixel values:
# -- Figura a mano: 189
# -- Rayo:          131
# -- Rectangulo:    110
# -- Circulo:       76
# -- Triangulo:     153
# -- Diamon:        154

# %%
mascara = (gray_img == figs_grays_values['circle_thr']+1) # this will return a boolean mascara
mascara = mascara.astype(np.uint8) * 255 # this converts the True elements from the boolean, into a 255 value, so I can show a picture
plt.imshow(mascara, cmap='gray')
plt.title('Aplicando la máscara')
plt.show()

# %%
# Calculamos el histograma
hist = cv2.calcHist([gray_img], [0], None, [260], [0, 260]) # [0] son los canales, None la máscara

# Documentation: cv2.calcHist(images, channels, mask, histSize, ranges)
# Channels: to get a histogram of a grayscale image, use [0]. To compute histogram for all three red, green and blue
# the channels would be [0,1,2]
# hitsize is the number of bins when computiong the histogram. It is a list, one for each channel
# ranges: the sange of possible pixel values (Normally [0,256]). Note that the end of the list is not inclusive, so we use 256

plt.plot(hist)
plt.grid()
plt.title('Histograma')
plt.show()

# Otra forma de mostrar el histograma (solo visualización)
plt.hist(gray_img.ravel(), bins=50)
plt.grid(True)
plt.show()

# %%
# Method to define threshold to extract multiple figures.

# Fijamos el umbral en base al histograma anterior
t = 150

# Extreaemos la máscara binaria
maxim = 255
_, mask = cv2.threshold(gray_img, t, maxim, cv2.THRESH_BINARY)

# Otra formas de extraer la máscara
# mask = gray_img.copy()
# mask = mask>t

# Visualizamos para corroborar
plt.imshow(mask, cmap='gray')
plt.title('Máscara t=' + str(t))
plt.show()

print(np.unique(mask)) # Atent@s a los formatos (bool, uint8, etc.)
# Out:
# [  0 255]

# %%
# Fijamos el umbral con el método de OTSU
t, mask = cv2.threshold(gray_img,0,1,cv2.THRESH_OTSU) # 0 es por defecto y 1 es el valor máximo de la máscara
print(np.unique(mask))

# Visualizamos para corroborar que se obtiene el mismo resultado
plt.imshow(mask, cmap='gray')
plt.title('Máscara Otsu t=' + str(t))
plt.show()
# Out:
# [0 1]

# %% [markdown]
# ### SEGMENTACIÓN MEDIANTE CONVERSIONES DE COLOR

# %%
# Imaginamos que queremos segmentar únicamente el círculo
img = cv2.imread('./figuras.png')
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img_rgb, cmap='gray')
plt.title('Imagen original')
plt.show()

# %%
# Obtenemos el canal rojo (la imagen está en formato OpenCV)
R = img[:,:,2]

plt.imshow(R, cmap='gray')
plt.title('Canal rojo')
plt.show()

print("Pixel values:")
print("-- Figura a mano:", R[100,100])
print("-- Rayo:         ", R[75,400])
print("-- Rectangulo:   ", R[250,100])
print("-- Circulo:      ", R[250,400])
print("-- Triangulo:    ", R[400,250])
print("-- Diamon:       ", R[450,500])
# Out:
# Pixel values:
# -- Figura a mano: 169
# -- Rayo:          0
# -- Rectangulo:    68
# -- Circulo:       255
# -- Triangulo:     16
# -- Diamon:        230

# %%
# Obtenemos el canal rojo tras pasar la imagen a RGB.
# Ahora utilizamos el canal 0, que corresponde al rojo
R = img_rgb[:,:,0]

plt.imshow(R, cmap='gray')
plt.title('Canal rojo')
plt.show()

print("Pixel values:")
print("-- Figura a mano:", R[100,100])
print("-- Rayo:         ", R[75,400])
print("-- Rectangulo:   ", R[250,100])
print("-- Circulo:      ", R[250,400])
print("-- Triangulo:    ", R[400,250])
print("-- Diamon:       ", R[450,500])
# Out:
# Pixel values:
# -- Figura a mano: 169
# -- Rayo:          0
# -- Rectangulo:    68
# -- Circulo:       255
# -- Triangulo:     16
# -- Diamon:        230

# %%
# Observamos el histograma
plt.hist(R.ravel(), bins=50)
plt.grid(True)
plt.show()
print(np.max(R))
# Out:
# 255

# %%
# Fijamos el umbral y extraemos la máscara
t=np.max(R)
mask = R.copy()
mask[mask<t] = 0

plt.imshow(mask, cmap='gray')
plt.title('ROI segmentada')
plt.show()

# %%
# Ejercicio individual
# Obtener una máscara con la imagen del rayo azul mediante segmentación por espacio de color

# Función para extraer los colores secundarios
def convert_to_CMYK(rgb_p):
    with np.errstate(invalid='ignore', divide='ignore'):
        K = 1 - np.max(rgb_p, axis=2)
        C = (1-rgb_p[:,:,0] - K)/(1-K)
        M = (1-rgb_p[:,:,1] - K)/(1-K)
        Y = (1-rgb_p[:,:,2] - K)/(1-K)
    CMYK = (np.dstack((C,M,Y,K))*255).astype('uint8')
    return CMYK

# Leer la imagen
img = cv2.imread('./figuras.png')
rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
rgb_p = rgb.astype('uint8')/255

# Extraer los colores secundarios
CMYK = convert_to_CMYK(rgb_p)

# Extraer los canales por separado
C,M,Y,K = CMYK[:,:,0], CMYK[:,:,1], CMYK[:,:,2], CMYK[:,:,3]
C = C.astype('uint8')
M = M.astype('uint8')
Y = Y.astype('uint8')
K = K.astype('uint8')

print("-- Rayo:", C[100,400])
# Since el rayo has a very high Cyan color (255), we will create the mask for
# a very high threshold (250)

# mascara de rayo
_, mask = cv2.threshold(C, 250,260, cv2.THRESH_BINARY)

# Visualizar la máscara
plt.imshow(mask, cmap='gray')
plt.title('ROI segmentada')
plt.show()
# Out:
# /tmp/ipython-input-2256801831.py:11: RuntimeWarning: invalid value encountered in cast
#   CMYK = (np.dstack((C,M,Y,K))*255).astype('uint8')
# -- Rayo: 255

# %% [markdown]
# ### SEGMENTACIÓN SEMÁNTICA CON DETECCIÓN DE BORDES

# %%
# SEGMENTACIÓN SEMÁNTICA CON DETECCIÓN DE BORDES
img = cv2.imread('./figuras.png')
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img_rgb)
plt.title('Imagen original')
plt.show()

# %%
# Aplicamos un filtro gaussiano para emborronar las altas frecuencias
img_gaus = cv2.GaussianBlur(img_rgb, (5,5), 0) # (5x5) es el tamaño del filtro y 0 es la desviación estándar
plt.imshow(img_gaus)
plt.show()

# %%
# Detección de bordes de Canny
canny = cv2.Canny(img_gaus, 255/3, 255) # minValue and maxValue. Canny recomienda que minValue sea 3 veces mayor que maxValue
kernel = np.ones((2,2), 'uint8')
canny = cv2.dilate(canny, kernel, iterations=3)
#canny = cv2.erode(canny, kernel, iterations=2)

plt.imshow(canny, cmap='gray')
plt.show()

# %%
# Rellenar objetos (solo rellena si no están en contacto con el límite de la imagen)
from scipy.ndimage import binary_fill_holes as bfh
bordes = canny.copy()
filled_bordes = bfh(bordes)

plt.imshow(filled_bordes.astype('uint8'), cmap='gray')
plt.title('cleaned lumen mask')
plt.show()

# %% [markdown]
# ### SEGMENTACIÓN POR CRECIMIENTO DE REGIONES (region growing)

# %%
# Cargar imagen
from skimage import io
import cv2
import numpy as np
import matplotlib.pyplot as plt
img = cv2.imread('./estrellas.png', 0)

plt.imshow(img, cmap='gray')
plt.show()

# %%
# Crear una copia de la imagen
mask = img.copy()

# Definir una imagen negra de referencia
h, w = img.shape
ref = np.zeros((h+2, w+2), np.uint8)

# Fijar la semilla. En este caso en la esquina superior izquierda (posición 0,0) para rellenar a partir de ahí
cv2.floodFill(mask, ref, (0,0), 0); # Como nos interesa rellenar de negro, utilizamos el 0 en la última posición

fig, ax = plt.subplots(1,2)
ax[0].imshow(img, cmap='gray'), ax[0].set_title('original')
ax[1].imshow(mask, cmap='gray'), ax[1].set_title('máscara')
plt.show()
# Out:
# 0
# 255
